# %% [markdown]
# # Calibration for existing modes (Seaport trips only)
# 1. Read current mode share and param file
# 2. Create new mode and new param files for calibration

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import openpyxl
import os
from shutil import copyfile
import glob
import sys
import importlib

# %%
os.getcwd()
# Out:
# 'C:\\Users\\xchang\\OneDrive - Cambridge Systematics\\Documents\\GitHub\\cs_fm_tool\\calibration'

# %%
os.chdir('..')

# %%
import cs_fm_tool
import config
import mode_choice.mc_util as util

# %%
fm = cs_fm_tool.CS_FM_Tool(config, 'projects/baseline_seaport_2018.yaml','param/perf_meas_nosm.yaml')
fm.load_inputs()
fm.setup()
fm.run()
util.write_study_area_mode_share_to_excel(fm.mc, r"C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\base_share_for_calib.xlsx")
# Out:
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.09 seconds
# ✓ skims read. Time elapsed: 8.46 seconds
# ✓ trip table read. Time elapsed: 11.51 seconds
# ✓ zonal variable tables generated. Time elapsed: 11.79 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 11.86 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 16.29 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 20.71 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 25.53 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 30.38 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 30.58 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 33.94 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 37.54 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 41.25 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 44.77 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 44.93 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 48.52 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 52.40 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 56.29 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 60.41 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 60.60 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 63.13 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 66.18 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 69.06 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 71.93 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 72.10 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 74.69 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 77.47 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 80.26 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 83.18 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 83.33 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 86.38 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 89.85 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 93.31 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 96.85 seconds

# %%
purposes =['HBW','HBO','NHB', 'HBSc1','HBSc2','HBSc3']
peak_veh = ['0_PK','1_PK','0_OP','1_OP']

# %%
def update_ASC(mc_summary, old_param, new_param):
    book = openpyxl.Workbook()
    book.save(new_param)

    for purpose in purposes:
        model = pd.read_excel(mc_summary,sheet_name = purpose,index_col = 0)

        modes = model.index
        df = pd.DataFrame(index = modes, columns = peak_veh)
        for pv in peak_veh:
            # compare if shares are higher or lower than what's supposed to happen
            _t = target[(target['Purpose'] == purpose) & (target['Segment'] == pv)]
            for mode in modes:
                target_share = _t[mode].values
                model_value = model.loc[mode][pv] # convert to share
                model_share = model_value / model[pv].sum()
                
                if target_share != 0 and abs((model_share - target_share)/target_share)<0.05:
                    df.loc[mode,pv] = 0
                elif target_share == 0 and abs(model_share - target_share)<0.05:
                    df.loc[mode,pv] = 0
                elif model_share != 0 and target_share == 0:
                    df.loc[mode,pv] = -1
                else:
                    df.loc[mode,pv] = np.log(target_share / model_share)[0]
        
        # read param, output new ASCs
        ASC = pd.read_excel(old_param, sheet_name = purpose,index_col = 0).filter(regex='ASC')
        param = pd.read_excel(old_param, sheet_name = purpose,index_col = 0).drop(ASC.columns,axis = 1)

        ASC.rename(columns = dict(zip(['ASC_'+pv for pv in peak_veh],peak_veh)),inplace = True)
        ASC_new = ASC + df

        # find 0-ASC mode
        for pv in peak_veh:
            ASC_0 = ASC.index[ASC[pv] == 0].values[0]
            ASC_new[pv] -= ASC_new.loc[ASC_0,pv]

        # make sure ASCs have absolute value <= 6    
        ASC_new[ASC_new>6] = 6
        ASC_new[ASC_new<-6] = -6
        
        # write to a new param file
        book = openpyxl.load_workbook(new_param)
        writer = pd.ExcelWriter(new_param,engine = 'openpyxl')
        writer.book = book

        param_new = pd.concat([param,
        ASC_new.rename(columns = dict(zip(peak_veh,['ASC_'+pv for pv in peak_veh])))],axis = 1)
        param_new.reset_index(inplace = True)
        param_new.to_excel(writer,sheet_name = purpose,index = False)
        writer.save()

# %%
def new_run(iter_dir,param_new):
    try: os.mkdir(iter_dir)
    except: print('Directory exists.')   
        
    fm = cs_fm_tool.CS_FM_Tool(config, 'projects/baseline_seaport_2018.yaml','param/perf_meas_nosm.yaml')
    fm.mc.param_file = param_new
    fm.load_inputs()
    fm.setup()
    fm.run()

    util.write_study_area_mode_share_to_excel(fm.mc,out_excel_fn = iter_dir + 'MC_mode_share.xlsx')

# %% [markdown]
# # Calibration loop for regular modes (without SM)

# %%
target = pd.read_csv(r"C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\MC_TargetShares_SPRT_2018.csv")
calibration_run_path = r'C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\'
mc_summary_file = calibration_run_path + "base_share_for_calib.xlsx"
param_file = r"C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\Seaport_data\param\param_calib_0716.xlsx"
param_new = calibration_run_path + "param_iter1.xlsx"

update_ASC(mc_summary_file, param_file, param_new)
new_run(calibration_run_path + r"iter_1\\",param_new)

for i in range(2,10):
    update_ASC(calibration_run_path+ "iter_{}\MC_mode_share.xlsx".format(i-1), 
               calibration_run_path+ "param_iter{}.xlsx".format(i-1),
               calibration_run_path + "param_iter{}.xlsx".format(i))
    
    iter_dir = calibration_run_path+r"iter_{}\\".format(i)
    new_run(iter_dir, calibration_run_path + "param_iter{}.xlsx".format(i))
# Out:
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.05 seconds
# ✓ skims read. Time elapsed: 7.67 seconds
# ✓ trip table read. Time elapsed: 10.32 seconds
# ✓ zonal variable tables generated. Time elapsed: 10.49 seconds
# Running for all purposes...
# Mode choice for HBW started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for HBW generated. Time elapsed: 10.51 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 14.89 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 18.98 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 23.22 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 27.25 seconds
# Mode choice for HBO started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for HBO generated. Time elapsed: 27.47 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 30.29 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 33.09 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 35.97 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 38.97 seconds
# Mode choice for NHB started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for NHB generated. Time elapsed: 39.12 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 42.68 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 46.48 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 50.09 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 53.81 seconds
# Mode choice for HBSc1 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for HBSc1 generated. Time elapsed: 53.99 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 56.57 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 59.34 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 62.06 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 64.78 seconds
# Mode choice for HBSc2 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for HBSc2 generated. Time elapsed: 64.93 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 67.55 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 70.55 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 73.32 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 75.88 seconds
# Mode choice for HBSc3 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter1.xlsx
# ✓ Parameter table for HBSc3 generated. Time elapsed: 76.03 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 79.07 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 82.62 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 85.87 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 89.10 seconds
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.08 seconds
# ✓ skims read. Time elapsed: 8.73 seconds
# ✓ trip table read. Time elapsed: 11.53 seconds
# ✓ zonal variable tables generated. Time elapsed: 11.69 seconds
# Running for all purposes...
# Mode choice for HBW started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for HBW generated. Time elapsed: 11.71 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 15.78 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 20.06 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 24.66 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 29.15 seconds
# Mode choice for HBO started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for HBO generated. Time elapsed: 29.33 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 32.75 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 36.14 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 39.55 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 43.04 seconds
# Mode choice for NHB started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for NHB generated. Time elapsed: 43.21 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 47.01 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 50.85 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 54.50 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 58.20 seconds
# Mode choice for HBSc1 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for HBSc1 generated. Time elapsed: 58.35 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 60.87 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 63.31 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 65.83 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 68.27 seconds
# Mode choice for HBSc2 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for HBSc2 generated. Time elapsed: 68.40 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 70.77 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 73.31 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 75.96 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 78.78 seconds
# Mode choice for HBSc3 started.
# C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\\param_iter2.xlsx
# ✓ Parameter table for HBSc3 generated. Time elapsed: 78.95 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 81.93 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 85.43 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 88.67 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 91.95 seconds

# %% [markdown]
# # Check post-calibration shares

# %%
fm = cs_fm_tool.CS_FM_Tool(config, 'projects/calibration_seaport_2018.yaml','param/perf_meas_nosm.yaml')
fm.load_inputs()
fm.setup()
fm.run()
# Out:
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.07 seconds
# ✓ skims read. Time elapsed: 7.76 seconds
# ✓ trip table read. Time elapsed: 10.47 seconds
# ✓ zonal variable tables generated. Time elapsed: 10.62 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 10.65 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 14.94 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 19.10 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 23.44 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 27.82 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 28.05 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 31.15 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 34.39 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 37.67 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 41.10 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 41.25 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 44.96 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 49.29 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 53.05 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 56.72 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 56.89 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 59.37 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 61.95 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 64.56 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 67.49 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 67.63 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 70.13 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 72.63 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 75.22 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 77.85 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 78.00 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 80.96 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 84.12 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 87.36 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 90.90 seconds

# %%
util.mode_share_by_subarea(fm.mc, r"C:\Egnyte\Shared\Projects\190077\1 - Existing Conditions\4 - CTPS\model_data\calibration\mode_share_iter9.csv")

# %% [markdown]
# # Smart Mobility (to be developed)

# %%
# change these paths
mc_script_source_path = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Scenarios\2040\\"
sm_calibration_run_path = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Utilities\smart mobility\smart mobility\\"
try:  os.mkdir(sm_calibration_run_path + 'SM calibration')
except: print('Directory exists.')

sys.path.append(mc_script_source_path)

# %%
import mode_choice; import mc_util; import config
mc = mode_choice.Mode_Choice(config,run_now = True, all_purposes = True)

# %%
# pick up results of the baseline run with no SM mode in parameter
current_share_file = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Scenarios\Test Output\MC_mode_share_20180801_163322.xlsx"
current_param_file = config.param_file

# %%
# Read baseline mode share output and desired SM shares, create new mode share target by redistributing mode shares using MAPC numbers
SM_target = pd.read_csv(sm_calibration_run_path+"SM_target_share.csv")
SM_target['SM_RA'] = SM_target['SM_RA'].str.rstrip('%').astype('float') / 100.0
SM_target['SM_SH'] = SM_target['SM_SH'].str.rstrip('%').astype('float') / 100.0

# SM_target file currently specifies: HBO: 5% SM_RA, 5% SM_SH
# Other purposes: 0.5% SM_RA, 0.5% SM_SH

# parse current mode share into share target format

purposes =['HBW','HBO','NHB', 'HBSc1','HBSc2','HBSc3']
peak_veh = ['0_PK','1_PK','0_OP','1_OP']
target_df = pd.DataFrame(columns = ['Purpose','PV','DA','SR2','SR3+','Bike','Walk','WAT','DAT_B','DAT_CR','DAT_RT','DAT_LB'])
for purpose in purposes:
    shares = pd.read_excel(current_share_file, sheet_name = purpose).T.loc[peak_veh].reset_index().rename(columns = {'index':'PV'})
    shares['Purpose'] = purpose
    # normalize
    mode_cols = shares.columns.drop(['PV','Purpose'])
    shares[mode_cols] = shares[mode_cols].divide(shares[mode_cols].sum(axis = 1), axis = 0)
    target_df = target_df.append(shares,)
target_df.fillna(0,inplace = True)

# %%
# redistribute mode share based on MAPC survey
walk_bike_factor = 112./669 # proportional split, walk and bike
drive_factor = 167./669 # DA, SR2, SR3+
transit_factor = 390./669 # WAT and DAT

def mode_share_adj(row):
    SM_total = row[['SM_RA','SM_SH']].sum()
    new_vals = dict.fromkeys(['Walk','Bike','DA','SR2','SR3+','WAT','DAT_B','DAT_CR','DAT_LB','DAT_RT'])
    new_vals['Walk'] = max(row.Walk - SM_total * walk_bike_factor * row.Walk / (row.Walk + row.Bike),0.5*row.Walk)
    new_vals['Bike'] = max(row.Bike - SM_total * walk_bike_factor * row.Bike / (row.Walk + row.Bike),0.5*row.Bike)
    new_vals['DA'] = max(row.DA - SM_total * drive_factor * row.DA / (row.DA + row.SR2 + row['SR3+']),0.5*row.DA)
    new_vals['SR2'] = max(row.SR2 - SM_total * drive_factor * row.SR2 / (row.DA + row.SR2 + row['SR3+']),0.5*row.SR2)
    new_vals['SR3+'] = max(row['SR3+'] - SM_total * drive_factor * row['SR3+'] / (row.DA + row.SR2 + row['SR3+']) , 0.5*row['SR3+'])
    new_vals['WAT'] = max(row.WAT - SM_total * transit_factor * row.WAT / (row.WAT + row.DAT_B + row.DAT_CR + row.DAT_LB + row.DAT_RT),0.5*row.WAT)
    new_vals['DAT_B'] = max(row.DAT_B - SM_total * transit_factor * row.DAT_B / (row.WAT + row.DAT_B + row.DAT_CR + row.DAT_LB + row.DAT_RT),0.5*row.DAT_B)
    new_vals['DAT_CR'] = max(row.DAT_CR - SM_total * transit_factor * row.DAT_CR / (row.WAT + row.DAT_B + row.DAT_CR + row.DAT_LB + row.DAT_RT),0.5*row.DAT_CR)
    new_vals['DAT_LB'] = max(row.DAT_LB - SM_total * transit_factor * row.DAT_LB / (row.WAT + row.DAT_B + row.DAT_CR + row.DAT_LB + row.DAT_RT),0.5*row.DAT_LB)
    new_vals['DAT_RT'] = max(row.DAT_RT - SM_total * transit_factor * row.DAT_RT / (row.WAT + row.DAT_B + row.DAT_CR + row.DAT_LB + row.DAT_RT),0.5*row.DAT_RT)
    
    #  if the share reduction is not enough, take shares from the top three
    if sum(list(new_vals.values())) + SM_total >1:
        share_to_reduce = (sum(list(new_vals.values())) + SM_total - 1)
        modes_to_reduce = (sorted(new_vals.keys(), key=lambda k: new_vals[k],reverse = True)[:3])
        for mode in modes_to_reduce:
            new_vals[mode]-= share_to_reduce / 3
    return pd.Series(new_vals)
    
    
target = target_df.merge(SM_target, on = ['Purpose','PV'],how ='left')
conv_mode_cols = target.columns.drop(['PV','Purpose','SM_RA','SM_SH'])
target[conv_mode_cols] =target.apply(mode_share_adj,axis = 1)

# %%
# add new modes in baseline mode share file
writer = pd.ExcelWriter(sm_calibration_run_path+'base_share_for_calib.xlsx',engine = 'openpyxl')
for purpose in purposes:
    shares = pd.read_excel(current_share_file,sheet_name = purpose)
    shares.loc['SM_RA'] = 0
    shares.loc['SM_SH'] = 0
    shares.to_excel(writer, sheet_name = purpose )
writer.save()

# %%
# create new param file that contains ASC for the two new modes
writer = pd.ExcelWriter(sm_calibration_run_path+'param_with_SM.xlsx',engine = 'openpyxl')
for purpose in purposes:
    param = pd.read_excel(current_param_file,sheet_name = purpose,index_col = 0)
    SM_nest = param.nest.max()+1
    SM_RA_nest_coef = 0.7
    SM_SH_nest_coef = 0.7
    if 'DA' in param.index:
        IVTT = param.loc['DA','IVTT']
        OVTT = param.loc['DA','OVTT']
        Cost = param.loc['DA','Cost']
    else: 
        IVTT = param.loc['SR2','IVTT']
        OVTT = param.loc['SR2','OVTT']
        Cost = param.loc['SR2','Cost']
    ASC = -6 
    SM_RA = pd.Series({'nest':SM_nest,'nest_coefficient':SM_RA_nest_coef,'IVTT':IVTT,'OVTT':OVTT,'Cost':Cost,
    'ASC_0_PK':ASC, 'ASC_1_PK':ASC,'ASC_0_OP':ASC, 'ASC_1_OP':ASC })
    SM_RA.name = 'SM_RA'

    SM_SH = pd.Series({'nest':SM_nest,'nest_coefficient':SM_SH_nest_coef,'IVTT':IVTT,'OVTT':OVTT,'Cost':Cost,
    'ASC_0_PK':ASC, 'ASC_1_PK':ASC,'ASC_0_OP':ASC, 'ASC_1_OP':ASC })
    SM_SH.name = 'SM_SH'    
    
    param = param.append([SM_RA,SM_SH])
    param.index.name = 'mode'
    param.to_excel(writer, sheet_name = purpose)

writer.save()
# Out:
# C:\Users\xchang\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\frame.py:5186: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   other = other.loc[:, self.columns]
# C:\Users\xchang\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
def update_ASC(mc_summary, old_param,new_param):
    book = openpyxl.Workbook()
    book.save(new_param)

    for purpose in purposes:
        model = pd.read_excel(mc_summary,sheet_name = purpose,index_col = 0)

        modes = model.index
        df = pd.DataFrame(index = modes, columns = peak_veh)
        for pv in peak_veh:
            # compare if shares are higher or lower than what's supposed to happen
            _t = target[(target['Purpose'] == purpose) & (target['PV'] == pv)]
            for mode in modes:
                target_share = _t[mode].values
                model_value = model.loc[mode][pv] # convert to share
                model_share = model_value / model[pv].sum()
                
                if target_share != 0 and abs((model_share - target_share)/target_share)<0.05:
                    df.loc[mode,pv] = 0
                elif target_share == 0 and abs(model_share - target_share)<0.05:
                    df.loc[mode,pv] = 0
                elif model_share != 0 and target_share == 0:
                    df.loc[mode,pv] = -1
                else:
                    df.loc[mode,pv] = np.log(target_share / model_share)[0]
        
        
        # read param, output new ASCs
        ASC = pd.read_excel(old_param, sheet_name = purpose,index_col = 0).filter(regex='ASC')
        param = pd.read_excel(old_param, sheet_name = purpose,index_col = 0).drop(ASC.columns,axis = 1)

        ASC.rename(columns = dict(zip(['ASC_'+pv for pv in peak_veh],peak_veh)),inplace = True)
        ASC_new = ASC + df

        # find 0-ASC mode
        for pv in peak_veh:
            ASC_0 = ASC.index[ASC[pv] == 0].values[0]
            ASC_new[pv] -= ASC_new.loc[ASC_0,pv]

        # make sure ASCs have absolute value <= 6    
        ASC_new[ASC_new>6] = 6
        ASC_new[ASC_new<-6] = -6
        
        # write to a new param file
        book = openpyxl.load_workbook(new_param)
        writer = pd.ExcelWriter(new_param,engine = 'openpyxl')
        writer.book = book

        param_new = pd.concat([param,
        ASC_new.rename(columns = dict(zip(peak_veh,['ASC_'+pv for pv in peak_veh])))],axis = 1)
        param_new.reset_index(inplace = True)
        param_new.to_excel(writer,sheet_name = purpose,index = False)
        writer.save()

# %%
def new_run(iter_dir,param_new):
    try: os.mkdir(iter_dir)
    except: print('Directory exists.')

    base_config = mc_script_source_path + "config.py"
    new_config = iter_dir+r"\config.py"

    # call mode choice, use new parameter file
    with open(base_config,'r') as cfg:
        txt = cfg.read()
        txt_new = txt.replace(r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Mode Choice\param_calib_0716.xlsx",param_new)
    with open(new_config,'w') as cfg1:
        cfg1.write(txt_new)

    # copy model run files
    for src in glob.iglob(mc_script_source_path + "m*.py"):
        fn = src.split('\\')[-1]
        copyfile(src, r"{}\{}".format(iter_dir,fn))

    # copy calibration notebook
    copyfile(sm_calibration_run_path + "base_share_for_calib.xlsx",iter_dir+r"\MC_mode_share.xlsx")

    # replace output directory in mc_util
    output_org = r'out_path + "MC_mode_share_{}.xlsx"'
    output_new = 'r"' + iter_dir+r'\MC_mode_share.xlsx"'
    with open(iter_dir + r"\mc_util.py",'r') as util:
        txt = util.read()
        txt_new = txt.replace(output_org,output_new)
    with open(iter_dir + r"\mc_util.py",'w') as util1:
        util1.write(txt_new)

    sys.path.insert(0, iter_dir)
    if 'mode_choice' in sys.modules:  
        del sys.modules["mode_choice"]

    if 'mc_util' in sys.modules:  
        del sys.modules["mc_util"]

    if 'config' in sys.modules:
        del sys.modules['config']

    import mode_choice; import mc_util; import config

    mc = mode_choice.Mode_Choice(config,run_now = True, all_purposes = True)

# %%
mc_summary_file = sm_calibration_run_path+ "base_share_for_calib.xlsx"
param_file =sm_calibration_run_path+"param_with_SM.xlsx"
param_new = sm_calibration_run_path"param_iter1.xlsx"

if 'mode_choice' in sys.modules:  
    del sys.modules["mode_choice"]

if 'mc_util' in sys.modules:  
    del sys.modules["mc_util"]

if 'config' in sys.modules:
    del sys.modules['config']

import mode_choice; import mc_util; import config

update_ASC(mc_summary_file, param_file, param_new)
new_run(sm_calibration_run_path + "SM calibration\iter_1",param_new)
# Out:
# C:\Users\xchang\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:25: RuntimeWarning: divide by zero encountered in true_divide
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.46 seconds
# ✓ skims read. Time elapsed: 30.14 seconds
# ✓ trip table read. Time elapsed: 44.17 seconds
# ✓ zonal variable tables generated. Time elapsed: 44.65 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 44.67 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 63.14 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 80.32 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 97.24 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 113.62 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 116.22 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 127.82 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 138.84 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 150.01 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 161.00 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 162.03 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 181.00 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 194.06 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 207.34 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 219.99 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 221.18 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 229.89 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 238.96 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 247.92 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 256.76 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 257.53 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 266.12 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 279.09 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 290.07 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 300.08 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 300.94 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 311.33 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 324.13 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 334.92 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 346.42 seconds

# %%
for i in range(2,10):
    update_ASC(sm_calibration_run_path+ "SM calibration\iter_{}\MC_mode_share.xlsx".format(i-1), 
               sm_calibration_run_path+ "SM calibration\param_iter{}.xlsx".format(i-1),
               sm_calibration_run_path + "SM calibration\param_iter{}.xlsx".format(i))
    iter_dir = sm_calibration_run_path+ "SM calibration\iter_{}".format(i)
    new_run(iter_dir, sm_calibration_run_path + "SM calibration\param_iter{}.xlsx".format(i))
# Out:
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.63 seconds
# ✓ skims read. Time elapsed: 28.81 seconds
# ✓ trip table read. Time elapsed: 41.36 seconds
# ✓ zonal variable tables generated. Time elapsed: 41.79 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 41.82 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 60.01 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 79.14 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 96.27 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 112.40 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 113.73 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 124.67 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 137.96 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 152.36 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 165.08 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 166.15 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 179.98 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 196.86 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 209.90 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 222.38 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 223.56 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 232.16 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 241.01 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 249.81 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 258.90 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 259.71 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 268.60 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 282.37 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 293.72 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 303.22 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 304.09 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 314.52 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 327.53 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 339.37 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 350.54 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.44 seconds
# ✓ skims read. Time elapsed: 28.07 seconds
# ✓ trip table read. Time elapsed: 40.10 seconds
# ✓ zonal variable tables generated. Time elapsed: 40.53 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 40.55 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 59.58 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 77.78 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 98.85 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 118.76 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 120.38 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 131.73 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 142.92 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 153.94 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 167.00 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 167.92 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 184.30 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 206.31 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 223.64 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 236.32 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 237.72 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 247.65 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 256.83 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 267.16 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 277.41 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 278.34 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 287.77 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 297.73 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 307.76 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 319.09 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 320.10 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 332.72 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 343.58 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 353.98 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 364.70 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.38 seconds
# ✓ skims read. Time elapsed: 28.40 seconds
# ✓ trip table read. Time elapsed: 40.76 seconds
# ✓ zonal variable tables generated. Time elapsed: 41.21 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 41.24 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 60.05 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 75.13 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 94.50 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 113.19 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 115.37 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 129.42 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 141.78 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 155.15 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 168.25 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 169.26 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 185.99 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 201.10 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 214.79 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 227.16 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 228.37 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 237.86 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 246.54 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 258.48 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 268.84 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 269.74 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 279.10 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 289.18 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 298.31 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 307.22 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 308.02 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 319.10 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 333.61 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 344.25 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 354.71 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.45 seconds
# ✓ skims read. Time elapsed: 28.40 seconds
# ✓ trip table read. Time elapsed: 40.26 seconds
# ✓ zonal variable tables generated. Time elapsed: 40.71 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 40.73 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 58.99 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 73.73 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 89.05 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 107.77 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 109.05 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 121.24 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 134.46 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 146.50 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 159.30 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 160.35 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 173.23 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 188.11 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 205.36 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 219.05 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 220.31 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 229.39 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 238.13 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 246.96 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 255.88 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 256.66 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 265.34 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 279.09 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 288.34 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 297.27 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 298.07 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 309.22 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 324.28 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 334.83 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 345.91 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.60 seconds
# ✓ skims read. Time elapsed: 28.67 seconds
# ✓ trip table read. Time elapsed: 40.55 seconds
# ✓ zonal variable tables generated. Time elapsed: 41.00 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 41.02 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 59.25 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 74.15 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 89.67 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 109.62 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 110.86 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 121.92 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 132.55 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 143.13 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 153.98 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 155.43 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 166.96 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 185.21 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 202.32 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 217.00 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 218.37 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 230.02 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 239.78 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 249.98 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 259.86 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 260.77 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 270.07 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 280.17 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 289.39 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 298.82 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 299.69 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 311.24 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 330.22 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 341.83 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 353.06 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.40 seconds
# ✓ skims read. Time elapsed: 28.26 seconds
# ✓ trip table read. Time elapsed: 40.11 seconds
# ✓ zonal variable tables generated. Time elapsed: 40.55 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 40.58 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 54.97 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 69.54 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 85.14 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 105.05 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 106.23 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 116.59 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 128.50 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 140.05 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 150.54 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 151.41 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 169.24 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 183.60 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 196.99 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 210.48 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 211.70 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 219.99 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 228.55 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 237.37 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 246.24 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 247.00 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 255.56 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 271.07 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 280.97 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 290.11 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 290.92 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 301.04 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 313.98 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 326.12 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 339.58 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.61 seconds
# ✓ skims read. Time elapsed: 28.46 seconds
# ✓ trip table read. Time elapsed: 40.35 seconds
# ✓ zonal variable tables generated. Time elapsed: 40.80 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 40.82 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 55.23 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 69.75 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 85.07 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 103.03 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 104.05 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 117.05 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 127.73 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 138.65 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 149.29 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 150.13 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 166.11 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 183.96 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 197.53 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 209.98 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 211.04 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 221.44 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 231.52 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 241.41 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 252.07 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 252.97 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 262.27 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 272.08 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 282.10 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 291.62 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 292.51 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 303.91 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 318.34 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 329.43 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 342.01 seconds
# Directory exists.
# ✓ TAZ / land use / parking / zonal variables read. Time elapsed: 0.70 seconds
# ✓ skims read. Time elapsed: 28.40 seconds
# ✓ trip table read. Time elapsed: 40.24 seconds
# ✓ zonal variable tables generated. Time elapsed: 40.69 seconds
# Running for all purposes...
# Mode choice for HBW started.
# ✓ Parameter table for HBW generated. Time elapsed: 40.71 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 55.34 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 70.15 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 85.73 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 105.64 seconds
# Mode choice for HBO started.
# ✓ Parameter table for HBO generated. Time elapsed: 107.27 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 118.55 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 129.70 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 142.27 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 153.26 seconds
# Mode choice for NHB started.
# ✓ Parameter table for NHB generated. Time elapsed: 155.07 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 173.30 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 194.28 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 206.78 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 220.06 seconds
# Mode choice for HBSc1 started.
# ✓ Parameter table for HBSc1 generated. Time elapsed: 221.31 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 230.90 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 239.56 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 248.22 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 257.20 seconds
# Mode choice for HBSc2 started.
# ✓ Parameter table for HBSc2 generated. Time elapsed: 257.98 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 266.30 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 278.56 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 291.70 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 300.91 seconds
# Mode choice for HBSc3 started.
# ✓ Parameter table for HBSc3 generated. Time elapsed: 301.83 seconds
# ✓ Trips for 0_PK calculated. Time elapsed: 313.07 seconds
# ✓ Trips for 1_PK calculated. Time elapsed: 324.62 seconds
# ✓ Trips for 0_OP calculated. Time elapsed: 338.56 seconds
# ✓ Trips for 1_OP calculated. Time elapsed: 349.73 seconds

# %%
# compare target and current model output (percentage deviation)
mc_summary = sm_calibration_run_path + "SM calibration\iter_9\MC_mode_share.xlsx"
for purpose in purposes:
    model = pd.read_excel(mc_summary,sheet_name = purpose,index_col = 0)

    modes = model.index
    df = pd.DataFrame(index = modes, columns = peak_veh)
    for pv in peak_veh:
        _t = target[(target['Purpose'] == purpose) & (target['PV'] == pv)]
        for mode in modes:
            target_share = _t[mode].values
            model_value = model.loc[mode][pv] # convert to share
            model_share = model_value / model[pv].sum()
            df.loc[mode,pv] = (abs((model_share - target_share)/target_share))[0] # percentage deviation of share
            
            
            #(model_share - target_share)[0]
    display(df.style.format('{:.2f}'))
# Out:
# <style  type="text/css" >
# </style>
# <table id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >DA</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.05</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >SR2</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.05</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >SR3+</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.05</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >Walk</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.05</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >Bike</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >WAT</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.05</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_RT</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow6_col1" class="data row6 col1" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >DAT_CR</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.00</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >DAT_LB</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.12</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row9" class="row_heading level0 row9" >DAT_B</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow9_col0" class="data row9 col0" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow9_col1" class="data row9 col1" >0.03</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow9_col2" class="data row9 col2" >0.01</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow9_col3" class="data row9 col3" >0.05</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row10" class="row_heading level0 row10" >SM_RA</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow10_col0" class="data row10 col0" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow10_col1" class="data row10 col1" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow10_col2" class="data row10 col2" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow10_col3" class="data row10 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dflevel0_row11" class="row_heading level0 row11" >SM_SH</th>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow11_col0" class="data row11 col0" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow11_col1" class="data row11 col1" >0.04</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow11_col2" class="data row11 col2" >0.02</td>
#         <td id="T_f62fd992_9725_11e8_b6ad_b8ca3ab092dfrow11_col3" class="data row11 col3" >0.04</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
# </style>
# <table id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >DA</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >SR2</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >Walk</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.04</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >Bike</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.03</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.03</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >WAT</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.04</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >DAT_CR</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.33</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.04</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_RT</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow6_col1" class="data row6 col1" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >DAT_LB</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.21</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.00</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >DAT_B</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.01</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.04</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row9" class="row_heading level0 row9" >SM_RA</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow9_col0" class="data row9 col0" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow9_col1" class="data row9 col1" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow9_col2" class="data row9 col2" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow9_col3" class="data row9 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dflevel0_row10" class="row_heading level0 row10" >SM_SH</th>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow10_col0" class="data row10 col0" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow10_col1" class="data row10 col1" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow10_col2" class="data row10 col2" >0.02</td>
#         <td id="T_f639c4ca_9725_11e8_a28e_b8ca3ab092dfrow10_col3" class="data row10 col3" >0.02</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
# </style>
# <table id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >DA</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >SR2</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >Walk</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.01</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.03</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >Bike</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.00</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.01</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.01</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >WAT</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.03</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.01</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >DAT_CR</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.00</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_RT</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.00</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow6_col1" class="data row6 col1" >1.42</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.17</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >DAT_LB</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.08</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.12</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.17</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >DAT_B</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.01</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.04</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.03</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row9" class="row_heading level0 row9" >SM_RA</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow9_col0" class="data row9 col0" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow9_col1" class="data row9 col1" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow9_col2" class="data row9 col2" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow9_col3" class="data row9 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dflevel0_row10" class="row_heading level0 row10" >SM_SH</th>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow10_col0" class="data row10 col0" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow10_col1" class="data row10 col1" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow10_col2" class="data row10 col2" >0.02</td>
#         <td id="T_f641b3f4_9725_11e8_ba2f_b8ca3ab092dfrow10_col3" class="data row10 col3" >0.06</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
# </style>
# <table id="T_f6495506_9725_11e8_8ac9_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >SR2</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >Walk</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.00</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.02</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >Bike</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.02</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >WAT</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.02</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >DAT_CR</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.04</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >DAT_RT</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.04</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.02</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_LB</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow6_col1" class="data row6 col1" >0.29</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.04</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >SM_RA</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.01</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >SM_SH</th>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.10</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.03</td>
#         <td id="T_f6495506_9725_11e8_8ac9_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.02</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
# </style>
# <table id="T_f650a806_9725_11e8_8c9e_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >SR2</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.03</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.00</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.03</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >Walk</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.00</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.01</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.00</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >Bike</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.01</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >WAT</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.04</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.01</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.05</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >DAT_CR</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.04</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.03</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.03</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >DAT_RT</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.01</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.04</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_LB</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.04</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow6_col1" class="data row6 col1" >0.01</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.00</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >SM_RA</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.03</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >SM_SH</th>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.03</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.05</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.02</td>
#         <td id="T_f650a806_9725_11e8_8c9e_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.18</td>
#     </tr></tbody>
# </table>
# <style  type="text/css" >
# </style>
# <table id="T_f6584924_9725_11e8_92a5_b8ca3ab092df" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >0_PK</th>
#         <th class="col_heading level0 col1" >1_PK</th>
#         <th class="col_heading level0 col2" >0_OP</th>
#         <th class="col_heading level0 col3" >1_OP</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row0" class="row_heading level0 row0" >DA</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow0_col0" class="data row0 col0" >0.04</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow0_col1" class="data row0 col1" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow0_col2" class="data row0 col2" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow0_col3" class="data row0 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row1" class="row_heading level0 row1" >SR2</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow1_col0" class="data row1 col0" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow1_col1" class="data row1 col1" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow1_col2" class="data row1 col2" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow1_col3" class="data row1 col3" >0.00</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row2" class="row_heading level0 row2" >Walk</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow2_col0" class="data row2 col0" >0.05</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow2_col1" class="data row2 col1" >0.03</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow2_col2" class="data row2 col2" >0.00</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow2_col3" class="data row2 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row3" class="row_heading level0 row3" >Bike</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow3_col0" class="data row3 col0" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow3_col1" class="data row3 col1" >0.04</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow3_col2" class="data row3 col2" >0.00</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow3_col3" class="data row3 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row4" class="row_heading level0 row4" >WAT</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow4_col0" class="data row4 col0" >0.04</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow4_col1" class="data row4 col1" >0.04</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow4_col2" class="data row4 col2" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow4_col3" class="data row4 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row5" class="row_heading level0 row5" >DAT_CR</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow5_col0" class="data row5 col0" >0.03</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow5_col1" class="data row5 col1" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow5_col2" class="data row5 col2" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow5_col3" class="data row5 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row6" class="row_heading level0 row6" >DAT_RT</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow6_col0" class="data row6 col0" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow6_col1" class="data row6 col1" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow6_col2" class="data row6 col2" >0.01</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow6_col3" class="data row6 col3" >0.01</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row7" class="row_heading level0 row7" >DAT_LB</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow7_col0" class="data row7 col0" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow7_col1" class="data row7 col1" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow7_col2" class="data row7 col2" >0.03</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow7_col3" class="data row7 col3" >0.02</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row8" class="row_heading level0 row8" >SM_RA</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow8_col0" class="data row8 col0" >0.05</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow8_col1" class="data row8 col1" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow8_col2" class="data row8 col2" >0.05</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow8_col3" class="data row8 col3" >0.04</td>
#     </tr>    <tr>
#         <th id="T_f6584924_9725_11e8_92a5_b8ca3ab092dflevel0_row9" class="row_heading level0 row9" >SM_SH</th>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow9_col0" class="data row9 col0" >0.05</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow9_col1" class="data row9 col1" >0.02</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow9_col2" class="data row9 col2" >0.05</td>
#         <td id="T_f6584924_9725_11e8_92a5_b8ca3ab092dfrow9_col3" class="data row9 col3" >0.04</td>
#     </tr></tbody>
# </table>

# %%
# Calibration for regular modes (without SM)
target = pd.read_csv(r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Utilities\smart mobility\regular modes\MC_TargetShares.csv")
calibration_run_path = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Utilities\smart mobility\regular modes\\"
mc_summary_file = calibration_run_path+ "base_share_for_calib.xlsx"
param_file ="X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Mode Choice\param_calib_0716.xlsx"
param_new = calibration_run_path"param_iter1.xlsx"

if 'mode_choice' in sys.modules:  
    del sys.modules["mode_choice"]

if 'mc_util' in sys.modules:  
    del sys.modules["mc_util"]

if 'config' in sys.modules:
    del sys.modules['config']

import mode_choice; import mc_util; import config

update_ASC(mc_summary_file, param_file, param_new)
new_run(calibration_run_path + "iter_1",param_new)

for i in range(2,10):
    update_ASC(calibration_run_path+ "iter_{}\MC_mode_share.xlsx".format(i-1), 
               calibration_run_path+ "param_iter{}.xlsx".format(i-1),
               calibration_run_path + "param_iter{}.xlsx".format(i))
    iter_dir = calibration_run_path+ "iter_{}".format(i)
    new_run(iter_dir, calibration_run_path + "param_iter{}.xlsx".format(i))

# %%
# trips by TNC
TNC_trips = pd.read_excel(r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Data\TNCs\MA-Rideshare-2017.xlsx")
# want number of trips going to/from each town by 0_veh hh and 1+ veh hh
data_path = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Data\CTPS_Data\ModelOutputs\2040\\"
pre_MC_trip_file = data_path + "pre_MC_trip_6_purposes.omx"
taz = pd.read_csv(data_path + "..\..\TAZ_and_Town_Polygons\SW_TAZ_2010.csv")
taz = taz[taz['ID_FOR_CS']<10000]
pre_MC_trip_table = mc_util.store_omx_as_dict(pre_MC_trip_file)

# %%
# rename towns in TNC data for matching.
TNC_trips.replace('BARNSTABLE','BARNSTABLE TOWN',inplace =True)
TNC_trips.replace('MANCHESTER','MANCHESTER-BY-THE-SEA',inplace =True)
unused_towns = set(TNC_trips.TOWN) - set(taz.TOWN.str.split(',',expand =True)[0])
TNC_trips.drop(TNC_trips.index[TNC_trips.TOWN.isin(unused_towns)],inplace =True)

# %%
import re
def find_trips(row):
    town = row.TOWN
    hh_0 = list(filter(re.compile('.*_0Auto').match, list(pre_MC_trip_table.keys())))
    hh_1 = list(filter(re.compile('.*_wAuto').match, list(pre_MC_trip_table.keys())))
    origin_trips_HH0 = 0
    dest_trips_HH0 = 0
    origin_trips_HH1 = 0
    dest_trips_HH1 = 0
    for i in hh_0:
        origin_trips_HH0 += pre_MC_trip_table[i][:2730,:2730][taz['TOWN']==town+',MA',:].sum()
        dest_trips_HH0 += pre_MC_trip_table[i][:2730,:2730][:,taz['TOWN']==town+',MA'].sum()
    for i in hh_1:
        origin_trips_HH1 += pre_MC_trip_table[i][:2730,:2730][taz['TOWN']==town+',MA',:].sum()
        dest_trips_HH1 += pre_MC_trip_table[i][:2730,:2730][:,taz['TOWN']==town+',MA'].sum()       
    return pd.Series({'origin_trips_HH0':origin_trips_HH0,
    'dest_trips_HH0':dest_trips_HH0,                  
    'origin_trips_HH1':origin_trips_HH1,    
    'dest_trips_HH1':dest_trips_HH1})

# %%
pd.concat([TNC_trips,TNC_trips.apply(find_trips,axis = 1)],axis = 1).to_csv(r'X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Data\TNCs\trips_veh_ownership.csv')

# %%
# smart mobility management policy parameter file
sm_baseline_param_file = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Scenarios\param_calib_SM.xlsx"
sm_mngpol_param_file = r"X:\Proj\2018\180021 - ISE_GHGMitAnly\001\Model\Scenarios\param_calib_SM_mngpol.xlsx"

writer = pd.ExcelWriter(sm_mngpol_param_file, engine = 'openpyxl')
for purpose in ['HBW', 'HBO', 'NHB', 'HBSc1', 'HBSc2', 'HBSc3']:
    bs_param = pd.read_excel(sm_baseline_param_file, sheet_name = purpose,index_col = 0)
    # raise SM_RA cost coefficient by 25%
    bs_param.loc['SM_RA','Cost'] *= 1.25
    bs_param.to_excel(writer, sheet_name = purpose)
writer.save()
